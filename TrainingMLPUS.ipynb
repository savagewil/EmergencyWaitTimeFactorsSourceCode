# %%
import pickle

import pandas as pd
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
training_data = pd.read_csv("Data/US/US_data_training.csv")
training_labels = pd.read_csv("Data/US/US_labels_training.csv")

# %%
training_labels
# Out:
#       OP_18b_score
# 0            120.0
# 1            213.0
# 2            137.0
# 3            157.0
# 4            185.0
# ...            ...
# 2897         128.0
# 2898         186.0
# 2899         193.0
# 2900         156.0
# 2901         130.0
#
# [2902 rows x 1 columns]

# %%
Y = training_labels

# %%
X = training_data
for col in X.columns:
    print(col)
    X[col] = X[col].astype(str).str.replace(',', '').astype(float)
    if X[col].isna().any():
        X[col] = X[col].fillna(0)
# Out:
# fips_code
# total_beds_7_day_avg
# all_adult_hospital_beds_7_day_avg
# all_adult_hospital_inpatient_beds_7_day_avg
# inpatient_beds_used_7_day_avg
# all_adult_hospital_inpatient_bed_occupied_7_day_avg
# inpatient_beds_used_covid_7_day_avg
# total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg
# total_adult_patients_hospitalized_confirmed_covid_7_day_avg
# total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg
# total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg
# inpatient_beds_7_day_avg
# total_icu_beds_7_day_avg
# total_staffed_adult_icu_beds_7_day_avg
# icu_beds_used_7_day_avg
# staffed_adult_icu_bed_occupancy_7_day_avg
# staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg
# staffed_icu_adult_patients_confirmed_covid_7_day_avg
# total_patients_hospitalized_confirmed_influenza_7_day_avg
# icu_patients_confirmed_influenza_7_day_avg
# total_patients_hospitalized_confirmed_influenza_and_covid_7_day_avg
# ...

# %%
model_hours = MLPRegressor(hidden_layer_sizes=(100, 100, 100, 100, 100, 100, 100, 100,),activation="tanh")

# %%
model_hours.fit(X,Y)
# Out:
# C:\Users\wills\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\wills\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPRegressor(activation='tanh',
#              hidden_layer_sizes=(100, 100, 100, 100, 100, 100, 100, 100))

# %%
(mean_absolute_error(Y, model_hours.predict(X)))
# Out:
# 34.45547104386412

# %%
testing_data = pd.read_csv("Data/US/US_data_testing.csv")
testing_labels = pd.read_csv("Data/US/US_labels_testing.csv")

# %%
Y_test = testing_labels
X_test = testing_data
for col in X_test.columns:
    X_test[col] = X_test[col].astype(str).str.replace(',', '').astype(float)
    if X_test[col].isna().any():
        X_test[col] = X_test[col].fillna(0)

# %%
(mean_absolute_error(Y_test, model_hours.predict(X_test)))
# Out:
# 33.94583104004492

# %%
model_bytes = pickle.dumps(model_hours)
print(len(model_bytes))
with open("Models/TrainingMLPUSModel.pkl", 'wb') as save_file:
    save_file.write(model_bytes)
# Out:
# 7885001

# %%
loaded_model = None
with open("Models/TrainingMLPUSModel.pkl", 'rb') as save_file:
    model_bytes = save_file.read()
    print(len(model_bytes))
    loaded_model = pickle.loads(model_bytes)
# Out:
# 7885001
